# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
today_date='2025-07-31'
# Out:
# StatementMeta(, 6e158bbd-e9b0-4f69-b5ec-fa5cc374aa2e, 5, Finished, Available, Finished)

# %%
df=spark.read.format('Delta').load('Tables/newcustomer')
df2=spark.read.format('Delta').load('Tables/filterbycountry1')

##df_6=df.union(df1).union(df2).union(df3).union(df4).union(df5)

#display(df)
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 7, Finished, Available, Finished)

# %%
from pyspark.sql.functions import *
# Get all executors and driver memory status
executors = sc.getExecutorMemoryStatus()
print(executors)
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 18, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 3
#       1 from pyspark.sql.functions import *
#       2 # Get all executors and driver memory status
# ----> 3 executors = sc.getExecutorMemoryStatus()
#       4 print(executors)
#
# AttributeError: 'SparkContext' object has no attribute 'getExecutorMemoryStatus'

# %%
# Number of executors
spark.conf.get("spark.executor.instances")  # may not be set if dynamic allocation is used
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 16, Finished, Available, Finished)
# '1'

# %%
# Auto broadcast join threshold
spark.conf.get("spark.sql.autoBroadcastJoinThreshold")
# Out:
# StatementMeta(, 72df1f44-b355-4554-b5ed-5900c2cd2cd9, 3, Finished, Available, Finished)
# '26214400'

# %%
# Executor memory
spark.conf.get("spark.executor.memory")
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 14, Finished, Available, Finished)
# '56g'

# %%
# Driver max result size (limits collect/show)
spark.conf.get("spark.driver.maxResultSize")
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 13, Finished, Available, Finished)
# '4096m'

# %%
# Driver memory
spark.conf.get("spark.driver.memory")
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 12, Finished, Available, Finished)
# '56g'

# %%
# Number of cores per executor
spark.conf.get("spark.executor.cores")
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 11, Finished, Available, Finished)
# '8'

# %%
spark.conf.get("spark.executor.memory")
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 5, Finished, Available, Finished)
# '56g'

# %%
spark.conf.get("spark.driver.maxResultSize")
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 4, Finished, Available, Finished)
# '4096m'

# %%
spark.conf.get("spark.driver.memory")
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 3, Finished, Available, Finished)
# '56g'

# %%
from pyspark.sql.functions import *
df3=df.join(broadcast(df2),"Customer_id")
df3.limit(100).show() 
#df3.count()
# Out:
# StatementMeta(, d1ac3195-d036-4b05-991a-cfb7995a0846, 10, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[29], line 3
#       1 from pyspark.sql.functions import *
#       2 df3=df.join(broadcast(df2),"Customer_id")
# ----> 3 df3.limit(100).show()
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/dataframe.py:945, in DataFrame.show(self, n, truncate, vertical)
#     885 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
#     886     """Prints the first ``n`` rows to the console.
#     887
#     888     .. versionadded:: 1.3.0
#    (...)
#     943     name | Bob
#     944     """
# --> 945     print(self._show_string(n, truncate, vertical))
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/dataframe.py:963, in DataFrame._show_string(self, n, truncate, vertical)
# ...

# %%
df3.explain(True)
# Out:
# StatementMeta(, 413e6ec8-d9b9-42d5-87d3-35a501e85895, 30, Finished, Available, Finished)
# == Parsed Logical Plan ==
# 'Join UsingJoin(Inner, [Customer_id])
# :- Relation [Index#3015,Customer_Id#3016,First_Name#3017,Last_Name#3018,Company#3019,City#3020,Country#3021,Phone1#3022,Phone2#3023,Email#3024,Subscription_Date#3025,Website#3026] parquet
# +- ResolvedHint (strategy=broadcast)
#    +- Relation [Index#3039,Customer_Id#3040,First_Name#3041,Last_Name#3042,Company#3043,City#3044,Country#3045,Phone1#3046,Phone2#3047,Email#3048,Subscription_Date#3049,Website#3050] parquet
#
# == Analyzed Logical Plan ==
# ...

# %%
df3.show(10)
# Out:
# StatementMeta(, 413e6ec8-d9b9-42d5-87d3-35a501e85895, 29, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df3.show(10)
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/dataframe.py:945, in DataFrame.show(self, n, truncate, vertical)
#     885 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
#     886     """Prints the first ``n`` rows to the console.
#     887
#     888     .. versionadded:: 1.3.0
#    (...)
#     943     name | Bob
#     944     """
# --> 945     print(self._show_string(n, truncate, vertical))
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/dataframe.py:963, in DataFrame._show_string(self, n, truncate, vertical)
#     957     raise PySparkTypeError(
#     958         error_class="NOT_BOOL",
# ...

# %%
spark.catalog.isCached(df)
# Out:
# StatementMeta(, a36a73a6-1ded-429c-bf06-2387ac9d87e5, 15, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 spark.catalog.isCached(df)
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/catalog.py:996, in Catalog.isCached(self, tableName)
#     956 def isCached(self, tableName: str) -> bool:
#     957     """
#     958     Returns true if the table is currently cached in-memory.
#     959
#    (...)
#     994     >>> _ = spark.sql("DROP TABLE tbl1")
#     995     """
# --> 996     return self._jcatalog.isCached(tableName)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/py4j/java_gateway.py:1314, in JavaMember.__call__(self, *args)
#    1313 def __call__(self, *args):
# -> 1314     args_command, temp_args = self._build_args(*args)
#    1316     command = proto.CALL_COMMAND_NAME +\
# ...

# %%
#spark.catalog.clearCache()
df.unpersist()
# Out:
# StatementMeta(, 413e6ec8-d9b9-42d5-87d3-35a501e85895, 22, Finished, Available, Finished)
# DataFrame[Index: string, Customer_Id: string, First_Name: string, Last_Name: string, Company: string, City: string, Country: string, Phone1: string, Phone2: string, Email: string, Subscription_Date: string, Website: string]

# %%
#df.cache()
df.is_cached
# Out:
# StatementMeta(, 413e6ec8-d9b9-42d5-87d3-35a501e85895, 24, Finished, Available, Finished)
# False

# %%
spark.conf.get("spark.sql.autoBroadcastJoinThreshold")
# Out:
# StatementMeta(, 413e6ec8-d9b9-42d5-87d3-35a501e85895, 31, Finished, Available, Finished)
# '26214400'

# %%
small_df=df2.select('Customer_Id','Index')
small_df.count()
# Out:
# StatementMeta(, 413e6ec8-d9b9-42d5-87d3-35a501e85895, 33, Finished, Available, Finished)
# 202913280

# %%
from pyspark.sql.functions import *
df3=df.join(broadcast(small_df),"Customer_id")
display(df3)
# Out:
# StatementMeta(, 413e6ec8-d9b9-42d5-87d3-35a501e85895, 34, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[101], line 3
#       1 from pyspark.sql.functions import *
#       2 df3=df.join(broadcast(small_df),"Customer_id")
# ----> 3 display(df3)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/notebookutils/visualization/display.py:278, in display(data, summary)
#     275     success = False
#     276     log4jLogger \
#     277         .error(f"display failed with error, language: python, error: {err}, correlationId={correlation_id}")
# --> 278     raise err
#     279 finally:
#     280     duration_ms = ceil((time.time() - start_time) * 1000)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/notebookutils/visualization/display.py:270, in display(data, summary)
#     267             _clear()
# ...

# %%
display(df)
# Out:
# StatementMeta(, 413e6ec8-d9b9-42d5-87d3-35a501e85895, 23, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, dd14f3ec-a95d-418e-a5c3-a9c45cdc3d27)

# %%
df4=df.union(df_new).union(df_new).union(df_new).union(df6)
# df8=df7.union(df7)
# df9=df8.union(df8).union(df8).union(df8)
# df9.count()
display(df4.filter(col('country')=='Korea').count())
# Out:
# StatementMeta(, 1ea8eb49-9126-4c30-86da-8515b5876023, 19, Finished, Available, Finished)
# 12472320

# %%
df9.write.format('delta').mode("overwrite").save('Tables/newcustomer_1')
# Out:
# StatementMeta(, 6e158bbd-e9b0-4f69-b5ec-fa5cc374aa2e, 39, Finished, Available, Finished)

# %%
df4.count()
# Out:
# StatementMeta(, 1ea8eb49-9126-4c30-86da-8515b5876023, 21, Finished, Available, Finished)
# 202913280

# %%
from pyspark.sql.functions import *
df1=df.withColumn('processed_date',lit(today_date))
display(df1)
# Out:
# StatementMeta(, 6e158bbd-e9b0-4f69-b5ec-fa5cc374aa2e, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 99049027-69de-47c5-aed1-ca97e4d76e5b)

# %%
df2=df1.select(['index','Company']).orderBy('index').show()
# Out:
# StatementMeta(, 6e158bbd-e9b0-4f69-b5ec-fa5cc374aa2e, 8, Finished, Available, Finished)
# +-------+--------------------+
# |  index|             Company|
# +-------+--------------------+
# |      1|        Patel-Deleon|
# |     10|         Rogers-Dean|
# |    100|  Mcpherson-Caldwell|
# |   1000|Brooks, Potts and...|
# |  10000|Bullock, Branch a...|
# | 100000|       Whitney-Giles|
# |1000000|          Santos PLC|
# |1000001|            Chen PLC|
# |1000002|      Liu-Washington|
# |1000003|Rogers, Roach and...|
# |1000004|         Oneal-Booth|
# |1000005|    Andersen-Skinner|
# |1000006|Bowman, Leon and ...|
# |1000007|Figueroa, Webb an...|
# |1000008|Pena, Dean and Ponce|
# |1000009|       Jarvis-Wilson|
# | 100001|Stevens, Ryan and...|
# |1000010|       Mckay-Alvarez|
# |1000011|     Acosta and Sons|
# |1000012|          Morrow Inc|
# +-------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import *
df3=df.groupBy('Country').agg(count('Customer_Id').alias('count_')).orderBy(desc('count_')).show()
display(df3)
# Out:
# StatementMeta(, 1ea8eb49-9126-4c30-86da-8515b5876023, 11, Finished, Available, Finished)
# +--------------------+-------+
# |             Country| count_|
# +--------------------+-------+
# |               Korea|1559040|
# |               Congo|1555968|
# |              Jordan| 809088|
# |             Vietnam| 805248|
# |            Suriname| 804000|
# |         Timor-Leste| 803712|
# |            Zimbabwe| 802560|
# |Slovakia (Slovak ...| 802464|
# |               Samoa| 801984|
# |         Netherlands| 801984|
# |Saint Kitts and N...| 801504|
# |    Christmas Island| 801312|
# |          Luxembourg| 800448|
# |            Colombia| 800448|
# |            Dominica| 799968|
# |            Cameroon| 799968|
# |           Swaziland| 799104|
# |              Kuwait| 798528|
# |South Georgia and...| 798432|
# |        Cook Islands| 797568|
# +--------------------+-------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col
df_new=df.filter(col('country')=='Korea')
display(df_new.count())
# Out:
# StatementMeta(, 1ea8eb49-9126-4c30-86da-8515b5876023, 13, Finished, Available, Finished)
# 1559040

# %%
display(df)
# Out:
# StatementMeta(, a36a73a6-1ded-429c-bf06-2387ac9d87e5, 6, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 display(df)
#
# NameError: name 'df' is not defined

# %%
df4.write.format('Delta').mode('Overwrite').partitionBy('Country').save('Tables/filterbycountry1')
# Out:
# StatementMeta(, 1ea8eb49-9126-4c30-86da-8515b5876023, 23, Finished, Available, Finished)

# %%
spark.catalog.listTables()
# Out:
# StatementMeta(, d58255c8-3e55-4ba4-9a28-17128f07157c, 7, Finished, Available, Finished)
# [Table(name='bronze_data', catalog='spark_catalog', namespace=['bronze'], description=None, tableType='MANAGED', isTemporary=False),
#  Table(name='LMS_09-01-2023', catalog='spark_catalog', namespace=['bronze'], description='', tableType='MANAGED', isTemporary=False),
#  Table(name='customers', catalog='spark_catalog', namespace=['bronze'], description='', tableType='MANAGED', isTemporary=False),
#  Table(name='newcustomer', catalog='spark_catalog', namespace=['bronze'], description=None, tableType='MANAGED', isTemporary=False),
#  Table(name='newcustomer_1', catalog='spark_catalog', namespace=['bronze'], description=None, tableType='MANAGED', isTemporary=False),
#  Table(name='partions60', catalog='spark_catalog', namespace=['bronze'], description=None, tableType='MANAGED', isTemporary=False),
# ...

# %%
spark.catalog.isCached("bronze_data")
# Out:
# StatementMeta(, a36a73a6-1ded-429c-bf06-2387ac9d87e5, 5, Finished, Available, Finished)
# False

# %%
df6=spark.read.format('Delta').load('Tables/bronze_data')
display(df6)
# Out:
# StatementMeta(, a36a73a6-1ded-429c-bf06-2387ac9d87e5, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, cbc0a989-5bd8-4b7c-8b5e-474c7debd76c)

# %%
df3.count()

# %%
from pyspark.sql.functions import *
df3=df2.join(broadcast(df),"Customer_id")
display(df3)
# Out:
# StatementMeta(, ea55b980-38b0-4cec-923e-55a803e2e41e, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 277bdde3-f8e9-4fea-a9a6-2d745649817f)

# %%
spark.conf.get("spark.executor.memory")
#spark.conf.get("spark.driver.memory")
# Out:
# StatementMeta(, ea55b980-38b0-4cec-923e-55a803e2e41e, 10, Finished, Available, Finished)
# '56g'

# %%
#spark.catalog.listTables()
#df.is_cached
spark.catalog.isCached(df)
# Out:
# StatementMeta(, d58255c8-3e55-4ba4-9a28-17128f07157c, 3, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #spark.catalog.listTables()
#       2 #df.is_cached
# ----> 3 spark.catalog.isCached(df)
#
# NameError: name 'df' is not defined

# %%
df_9.write.format('delta').mode("overwrite").save('Tables/newcustomer_1')
# Out:
# StatementMeta(, 6e158bbd-e9b0-4f69-b5ec-fa5cc374aa2e, 36, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df_9.write.format('delta').mode("overwrite").save('Tables/newcustomer_1')
#
# NameError: name 'df_9' is not defined

# %%
df=spark.read.format('delta').load('Tables/newcustomer_1')
# Out:
# StatementMeta(, 8fbe6a3b-6042-4417-8456-6b36d9ca9ff4, 3, Finished, Available, Finished)

# %%
df.count()
# Out:
# StatementMeta(, 8fbe6a3b-6042-4417-8456-6b36d9ca9ff4, 4, Finished, Available, Finished)
# 192000000

# %%
df = df.repartition(60)
df.write.format("delta").save("Tables/partions60")
# Out:
# StatementMeta(, 44669081-7031-4c41-8eb7-2df9e63bc3e4, 6, Finished, Available, Finished)

# %%
df.write.partitionBy('Country').format('Delta').save('Tables/bycountry')
# Out:
# StatementMeta(, 44669081-7031-4c41-8eb7-2df9e63bc3e4, 7, Finished, Available, Finished)

# %%
df.explain()
# Out:
# StatementMeta(, 44669081-7031-4c41-8eb7-2df9e63bc3e4, 8, Finished, Available, Finished)
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=true
# +- == Final Plan ==
#    ShuffleQueryStage 0
#    +- Exchange RoundRobinPartitioning(60), REPARTITION_BY_NUM, [plan_id=506]
#       +- *(1) ColumnarToRow
#          +- FileScan parquet [Index#756,Customer_Id#757,First_Name#758,Last_Name#759,Company#760,City#761,Country#762,Phone1#763,Phone2#764,Email#765,Subscription_Date#766,Website#767] Batched: true, DataFilters: [], Format: Parquet, Location: PreparedDeltaFileIndex(1 paths)[abfss://8e1c36a2-a771-49fa-8ce2-e9aeaaa37b7a@onelake.dfs.fabric.m..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<Index:string,Customer_Id:string,First_Name:string,Last_Name:string,Company:string,City:str...
# +- == Initial Plan ==
#    Exchange RoundRobinPartitioning(60), REPARTITION_BY_NUM, [plan_id=497]
# ...

# %%
df1=spark.read.format('Delta').load('Tables/newcustomer')
df1.count()
# Out:
# StatementMeta(, 212718e6-fd51-4a0b-b87a-52e6b0b44ca2, 6, Finished, Available, Finished)
# 12000000

# %%
df2=df1.join(df,'Customer_id','inner')
df2.count()
# Out:
# StatementMeta(, 44669081-7031-4c41-8eb7-2df9e63bc3e4, 13, Finished, Available, Finished)
# 1152000000

# %%
df_4= df1.coalesce(10)
df_4.write.format('Delta').save('Tables/coalensce10')
# Out:
# StatementMeta(, 212718e6-fd51-4a0b-b87a-52e6b0b44ca2, 7, Finished, Available, Finished)

# %%
df_4.rdd.getNumPartitions()
# Out:
# StatementMeta(, 212718e6-fd51-4a0b-b87a-52e6b0b44ca2, 8, Finished, Available, Finished)
# 8

# %%
df=spark.read.format('Delta').load('Tables/newcustomer')
display(df)
# Out:
# StatementMeta(, 244f029a-48a4-4f7b-a5de-26ffff5174dc, 12, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 182714a3-90e1-401b-b63e-d133fe022568)

# %%
df1=spark.read.format('Delta').load('Tables/bycountry')
display(df1)
# Out:
# StatementMeta(, 244f029a-48a4-4f7b-a5de-26ffff5174dc, 14, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 7a5d1cb4-f23e-4788-92e5-842c502404fc)

# %%
df=df.filter(col('Country')=='Korea')
display(df)
# Out:
# StatementMeta(, 244f029a-48a4-4f7b-a5de-26ffff5174dc, 16, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 584cab1e-bc13-4890-880c-69ab4d56a5dc)

# %%
df1=df1.filter(col('Country')=='Korea')
display(df1)
# Out:
# StatementMeta(, 244f029a-48a4-4f7b-a5de-26ffff5174dc, 17, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ee37b56d-fa4c-499a-aedf-e393ea309c62)
